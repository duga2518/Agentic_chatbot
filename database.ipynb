# %%
import logging

# %%
logging.basicConfig(filename='app.log', 
                    level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
logger.info("This will be saved to app.log")

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    logger.exception("Division by zero encountered during development")

# %%
with open('app.log','r') as log_file:
				print(log_file.read())
# Out:
# 2025-11-16 00:57:17,874 - INFO - This will be saved to app.log
# 2025-11-16 00:57:21,673 - ERROR - Division by zero encountered during development
# Traceback (most recent call last):
#   File "C:\Users\durga\AppData\Local\Temp\ipykernel_18932\2207706132.py", line 2, in <module>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero
# 2025-11-16 00:58:04,591 - DEBUG - Debugging information: variable x has value test_value
